# %%
# Let's create an audio question relevant to an ecommerce business leveraging to test the IVR with LLM model


from gtts import gTTS
from pydub import AudioSegment
from google.colab import files

# Let define the text to convert to audio
text = "Are there any special deals or discounts on electronics today?"

# Create an MP3 file using gTTS
tts = gTTS(text, lang="en")
mp3_filename = "question.mp3"
tts.save(mp3_filename)
print(f"MP3 file '{mp3_filename}' created.")

# Convert the MP3 file to WAV format using pydub
wav_filename = "question.wav"
audio = AudioSegment.from_mp3(mp3_filename)
audio.export(wav_filename, format="wav")
print(f"WAV file '{wav_filename}' created.")

# Provide a download link for the WAV file
files.download(wav_filename)

# %%
# Let's install Dependencies
#!pip install transformers gTTS SpeechRecognition pydub -q
#!apt-get install ffmpeg -qq

# Let's import Libraries
import os
import speech_recognition as sr
from google.colab import files
from transformers import AutoTokenizer, AutoModelForCausalLM
from gtts import gTTS
import IPython.display as ipd



# Let's efine a Function to Transcribe Audio to Text
def audio_to_text(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)
    try:
        text = recognizer.recognize_google(audio_data)
        print("Transcribed text:", text)
    except Exception as e:
        text = ""
        print("Error transcribing audio:", e)
    return text

# Let's define a Function to Generate a Response with Falcon
def generate_response(user_input):
    prompt = f"User: {user_input}\nSystem:"
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_new_tokens=50)
    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    response = full_output.split("System:")[-1].strip()
    print("Model response:", response)
    return response



# Let's upload the audio file question I created to test the IVR
print("Please upload your audio file:")
uploaded_files = files.upload()

for filename in uploaded_files.keys():
    print("Processing file:", filename)

    # Convert speech to text
    user_text = audio_to_text(filename)

    if user_text:
        # Generate a response using the LLM
        response_text = generate_response(user_text)

        # Convert the response to speech and play it
        response_audio = text_to_speech(response_text)
        display(response_audio)
    else:
        print("No valid transcription. Please try again with a clearer audio file.")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Please upload your audio file:
#      <input type="file" id="files-90c8d122-1c3a-4d49-bd23-94dcc518b136" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90c8d122-1c3a-4d49-bd23-94dcc518b136">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
